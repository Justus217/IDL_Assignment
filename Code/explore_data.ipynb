# %%
import torch

# %%
data_path = "../data/cells.pt" 

data = torch.load(data_path)

# %%
data.keys()
# Out:
# dict_keys(['train_images', 'train_labels', 'test_images', 'test_labels'])

# %%
print(data["train_images"].shape)
print(data["test_images"].shape)
print(data["train_labels"].shape)
print(data["test_labels"].shape)
# Out:
# torch.Size([13671, 3, 64, 64])
# torch.Size([3421, 3, 64, 64])
# torch.Size([13671, 1])
# torch.Size([3421, 1])

# %%
unique_labels = torch.unique(data['train_labels'])

# Anzahl der Klassen berechnen
num_classes = unique_labels.numel()

print(f"Einzigartige Labels im Datensatz: {unique_labels.tolist()}")
print(f"Anzahl der Klassen (num_classes): {num_classes}")
